# %% [markdown]
# Hi Eve,
#
# I’m checking the MPB logic for form_ans_date in silver_form_answer.
#
# There are two MPB blocks in the notebook.
#
# The first block is for epicrisis / anamnesis answers. This block currently uses TO_DATE(an.created_at) from silver_drj_anamnesises for form_ans_date.
#
# The second block is for assessment / clinical score answers. The definition says form_ans_date should be extracted from the created_at date in the drj_assessmentresults table, so I’m planning to use the date part of drj_assessmentresults.created_at for this block.
#
# Could you please confirm whether the first block should continue using anamnesis.created_at for form_ans_date, or should it remain null / use a different date?
#
# For our understanding: the second block clearly matches the clinical scores definition, but the first block is not using drj_assessmentresults, so I want to confirm the correct source date before changing anything.
