# %%
model

# %%
src_sys1 AS (
    SELECT DISTINCT
        concat(cast(r.id_organisation_source as string), '-', cast(r.service_offered as string)) AS service_src_id,
        c.configured_list_option AS service_src_name,
        cast(r.id_organisation_source as string) AS service_src_sys_inst_id
    FROM silver.silver_sone_srreferralin r
    LEFT JOIN silver.silver_sone_srconfiguredlistoption c
        ON r.service_offered = cast(c.id as int)
        -- Ideally also:
        -- AND r.id_organisation_source = c.id_organisation_source
    WHERE r.id_organisation_source IS NOT NULL
      AND c.configured_list_option IS NOT NULL
      AND r.removed_data = 0
),

# %%
SELECT
    ae.id AS activity_entry_id,
    ah.id AS activity_header_id,
    ah.service_type_id,
    ast.description AS service_type_name,
    asv.service_id,
    srv.description AS service_name,
    ae.activity_type_id,
    atp.description AS activity_type_name,
    CONCAT(
        ast.description, ' ',
        srv.description, ' ',
        atp.description
    ) AS cprod_name,
    CONCAT(
        CAST(ah.service_type_id AS STRING),
        '_',
        CAST(asv.service_id AS STRING),
        '_',
        CAST(ae.activity_type_id AS STRING)
    ) AS cprod_src_id,
    asv.is_primary
FROM silver_wip_activityentry ae
LEFT JOIN silver_wip_activityheader ah
    ON ae.activity_header_id = ah.id
LEFT JOIN silver_wip_activityservice asv
    ON ae.activity_service_id = asv.id
LEFT JOIN silver_wip_servicetype ast
    ON ah.service_type_id = ast.id
LEFT JOIN silver_wip_service srv
    ON asv.service_id = srv.id
LEFT JOIN silver_wip_activitytype atp
    ON ae.activity_type_id = atp.id
WHERE asv.is_primary = true
LIMIT 100;

# %%
SELECT
    ae.id AS activity_entry_id,
    ah.id AS activity_header_id,
    ah.service_type_id,
    ast.description AS service_type_name,
    asv.service_id,
    srv.description AS service_name,
    ae.activity_type_id,
    atp.description AS activity_type_name,
    CONCAT(
        ast.description, ' ',
        srv.description, ' ',
        atp.description
    ) AS cprod_name,
    CONCAT(
        CAST(ah.service_type_id AS STRING),
        '_',
        CAST(asv.service_id AS STRING),
        '_',
        CAST(ae.activity_type_id AS STRING)
    ) AS cprod_src_id,
    asv.is_primary
FROM silver_wip_activityentry ae
LEFT JOIN silver_wip_activityheader ah
    ON ae.activity_header_id = ah.id
LEFT JOIN silver_wip_activityservice asv
    ON ae.activity_service_id = asv.id
LEFT JOIN silver_wip_servicetype ast
    ON ah.service_type_id = ast.id
LEFT JOIN silver_wip_service srv
    ON asv.service_id = srv.id
LEFT JOIN silver_wip_activitytype atp
    ON ae.activity_type_id = atp.id
WHERE asv.is_primary = true
LIMIT 100

# %%
SELECT
    ae.id AS activity_entry_id,
    ah.id AS activity_header_id,
    ah.service_type_id,
    ast.description AS service_type_name,
    asv.service_id,
    srv.description AS service_name,
    ae.activity_type_id,
    atp.description AS activity_type_name,
    CONCAT(
        ast.description, ' ',
        srv.description, ' ',
        atp.description
    ) AS cprod_name,
    CONCAT(
        CAST(ah.service_type_id AS STRING),
        '_',
        CAST(asv.service_id AS STRING),
        '_',
        CAST(ae.activity_type_id AS STRING)
    ) AS cprod_src_id,
    asv.is_primary
FROM silver_wip_activityentry ae
LEFT JOIN silver_wip_activityheader ah
    ON ae.activity_header_id = ah.id
LEFT JOIN silver_wip_activityservice asv
    ON ae.activity_service_id = asv.id
LEFT JOIN silver_wip_servicetype ast
    ON ah.service_type_id = ast.id
LEFT JOIN silver_wip_service srv
    ON asv.service_id = srv.id
LEFT JOIN silver_wip_activitytype atp
    ON ae.activity_type_id = atp.id
WHERE asv.is_primary = true
  AND ah.id IS NOT NULL
  AND ah.service_type_id IS NOT NULL
  AND asv.service_id IS NOT NULL
  AND ae.activity_type_id IS NOT NULL
LIMIT 100

# %% [markdown]
# gggg

# %%
SELECT
    ae.id AS activity_entry_id,
    ah.id AS activity_header_id,
    ah.service_type_id,
    ast.description AS service_type_name,
    asv.service_id,
    srv.description AS service_name,
    ae.activity_type_id,
    atp.description AS activity_type_name,
    CONCAT(
        ast.description, ' ',
        srv.description, ' ',
        atp.description
    ) AS cprod_name,
    CONCAT(
        CAST(ah.service_type_id AS STRING),
        '_',
        CAST(asv.service_id AS STRING),
        '_',
        CAST(ae.activity_type_id AS STRING)
    ) AS cprod_src_id,
    asv.is_primary
FROM silver_wip_activityentry ae
LEFT JOIN silver_wip_activityheader ah
    ON ae.activity_header_id = ah.id
LEFT JOIN silver_wip_activityservice asv
    ON ae.activity_service_id = asv.id
LEFT JOIN silver_wip_servicetype ast
    ON ah.service_type_id = ast.id
LEFT JOIN silver_wip_service srv
    ON asv.service_id = srv.id
LEFT JOIN silver_wip_activitytype atp
    ON ae.activity_type_id = atp.id
WHERE asv.is_primary = true
  AND ah.id IS NOT NULL
  AND ah.service_type_id IS NOT NULL
  AND asv.service_id IS NOT NULL
  AND ae.activity_type_id IS NOT NULL
LIMIT 100

# %%
SELECT DISTINCT
    CONCAT(
        ast.description, ' ',
        srv.description, ' ',
        atp.description
    ) AS cprod_name,
    'WIP001' AS cprod_src_sys_inst_id,
    CONCAT(
        CAST(ah.service_type_id AS STRING),
        '_',
        CAST(asv.service_id AS STRING),
        '_',
        CAST(ae.activity_type_id AS STRING)
    ) AS cprod_src_id
FROM silver_wip_activityentry ae
LEFT JOIN silver_wip_activityheader ah
    ON ae.activity_header_id = ah.id
LEFT JOIN silver_wip_activityservice asv
    ON ae.activity_service_id = asv.id
LEFT JOIN silver_wip_servicetype ast
    ON ah.service_type_id = ast.id
LEFT JOIN silver_wip_service srv
    ON asv.service_id = srv.id
LEFT JOIN silver_wip_activitytype atp
    ON ae.activity_type_id = atp.id
WHERE asv.is_primary = true
  AND ah.id IS NOT NULL
  AND ah.service_type_id IS NOT NULL
  AND asv.service_id IS NOT NULL
  AND ae.activity_type_id IS NOT NULL

# %%
SELECT DISTINCT
    CONCAT(
        ast.description, ' ',
        srv.description, ' ',
        atp.description
    ) AS cprod_name,
    'WIP001' AS cprod_src_sys_inst_id,
    CONCAT(
        CAST(ah.service_type_id AS STRING),
        '_',
        CAST(asv.service_id AS STRING),
        '_',
        CAST(ae.activity_type_id AS STRING)
    ) AS cprod_src_id
FROM silver_wip_activityentry ae
LEFT JOIN silver_wip_activityheader ah
    ON ae.activity_header_id = ah.id
LEFT JOIN silver_wip_activityservice asv
    ON ae.activity_service_id = asv.id
LEFT JOIN silver_wip_servicetype ast
    ON ah.service_type_id = ast.id
LEFT JOIN silver_wip_service srv
    ON asv.service_id = srv.id
LEFT JOIN silver_wip_activitytype atp
    ON ae.activity_type_id = atp.id
WHERE asv.is_primary = true
  AND ah.id IS NOT NULL
  AND ah.service_type_id IS NOT NULL
  AND asv.service_id IS NOT NULL
  AND ae.activity_type_id IS NOT NULL

# %%
WITH wip_care_product AS (
    SELECT DISTINCT
        CONCAT(
            ast.description, ' ',
            srv.description, ' ',
            atp.description
        ) AS cprod_name,
        'WIP001' AS cprod_src_sys_inst_id,
        CONCAT(
            CAST(ah.service_type_id AS STRING),
            '_',
            CAST(asv.service_id AS STRING),
            '_',
            CAST(ae.activity_type_id AS STRING)
        ) AS cprod_src_id
    FROM silver_wip_activityentry ae
    LEFT JOIN silver_wip_activityheader ah
        ON ae.activity_header_id = ah.id
    LEFT JOIN silver_wip_activityservice asv
        ON ae.activity_service_id = asv.id
    LEFT JOIN silver_wip_servicetype ast
        ON ah.service_type_id = ast.id
    LEFT JOIN silver_wip_service srv
        ON asv.service_id = srv.id
    LEFT JOIN silver_wip_activitytype atp
        ON ae.activity_type_id = atp.id
    WHERE asv.is_primary = true
      AND ah.id IS NOT NULL
      AND ah.service_type_id IS NOT NULL
      AND asv.service_id IS NOT NULL
      AND ae.activity_type_id IS NOT NULL
)

SELECT
    w.cprod_name,
    w.cprod_src_sys_inst_id,
    w.cprod_src_id
FROM wip_care_product w
LEFT JOIN silver_rdm_care_product r
    ON w.cprod_src_sys_inst_id = r.cprod_src_sys_inst_id
   AND w.cprod_src_id = r.cprod_src_id
WHERE r.cprod_src_id IS NULL

# %%
-- WIP Care Product derivation
-- Purpose:
-- Derive new Care Product records for WIP and return only the 3 required columns:
-- 1. cprod_name
-- 2. cprod_src_sys_inst_id
-- 3. cprod_src_id

WITH wip_care_product AS (

    SELECT DISTINCT

        -- cprod_name:
        -- Monday definition for WIP says:
        -- Service Type + Service Activity + Activity Type
        CONCAT(
            ast.description, ' ',
            srv.description, ' ',
            atp.description
        ) AS cprod_name,

        -- cprod_src_sys_inst_id:
        -- Temporarily hardcoded as WIP001
        -- This can be made dynamic later once Source System Instance reference table is available in Fabric
        'WIP001' AS cprod_src_sys_inst_id,

        -- cprod_src_id:
        -- Monday definition for WIP says:
        -- Service Type ID + Service Activity ID + Activity Type ID
        CONCAT(
            CAST(ah.service_type_id AS STRING),
            '_',
            CAST(asv.service_id AS STRING),
            '_',
            CAST(ae.activity_type_id AS STRING)
        ) AS cprod_src_id

    FROM silver_wip_activityentry ae

    -- Join to activity header to get service_type_id
    LEFT JOIN silver_wip_activityheader ah
        ON ae.activity_header_id = ah.id

    -- Join to activity service to get service_id
    LEFT JOIN silver_wip_activityservice asv
        ON ae.activity_service_id = asv.id

    -- Join to service type lookup to get service type description
    LEFT JOIN silver_wip_servicetype ast
        ON ah.service_type_id = ast.id

    -- Join to service lookup to get service description
    LEFT JOIN silver_wip_service srv
        ON asv.service_id = srv.id

    -- Join to activity type lookup to get activity type description
    LEFT JOIN silver_wip_activitytype atp
        ON ae.activity_type_id = atp.id

    WHERE asv.is_primary = true
      -- Use only primary service mapping for care product derivation
      AND ah.id IS NOT NULL
      AND ah.service_type_id IS NOT NULL
      AND asv.service_id IS NOT NULL
      AND ae.activity_type_id IS NOT NULL
      -- Exclude incomplete/null combinations
)

SELECT
    w.cprod_name,
    w.cprod_src_sys_inst_id,
    w.cprod_src_id
FROM wip_care_product w

-- Compare with already ingested RDM Care Product records
LEFT JOIN silver_rdm_care_product r
    ON w.cprod_src_sys_inst_id = r.cprod_src_sys_inst_id
   AND w.cprod_src_id = r.cprod_src_id

-- Keep only new records not already present in silver_rdm_care_product
WHERE r.cprod_src_id IS NULL

# %%
-- Create add table for new WIP Care Product records
-- Target table: silver_rdm_care_product_add
-- Only the 3 required columns are populated:
-- 1. cprod_name
-- 2. cprod_src_sys_inst_id
-- 3. cprod_src_id

CREATE OR REPLACE TABLE silver_rdm_care_product_add AS

WITH wip_care_product AS (

    SELECT DISTINCT

        -- cprod_name:
        -- Derived using Service Type + Service + Activity Type
        CONCAT(
            ast.description, ' ',
            srv.description, ' ',
            atp.description
        ) AS cprod_name,

        -- cprod_src_sys_inst_id:
        -- Temporarily hardcoded for WIP
        'WIP001' AS cprod_src_sys_inst_id,

        -- cprod_src_id:
        -- Derived using Service Type ID + Service ID + Activity Type ID
        CONCAT(
            CAST(ah.service_type_id AS STRING),
            '_',
            CAST(asv.service_id AS STRING),
            '_',
            CAST(ae.activity_type_id AS STRING)
        ) AS cprod_src_id

    FROM silver_wip_activityentry ae

    -- Get service type id
    LEFT JOIN silver_wip_activityheader ah
        ON ae.activity_header_id = ah.id

    -- Get service id and primary service flag
    LEFT JOIN silver_wip_activityservice asv
        ON ae.activity_service_id = asv.id

    -- Get service type description
    LEFT JOIN silver_wip_servicetype ast
        ON ah.service_type_id = ast.id

    -- Get service description
    LEFT JOIN silver_wip_service srv
        ON asv.service_id = srv.id

    -- Get activity type description
    LEFT JOIN silver_wip_activitytype atp
        ON ae.activity_type_id = atp.id

    WHERE asv.is_primary = true
      AND ah.id IS NOT NULL
      AND ah.service_type_id IS NOT NULL
      AND asv.service_id IS NOT NULL
      AND ae.activity_type_id IS NOT NULL
)

SELECT
    w.cprod_name,
    w.cprod_src_sys_inst_id,
    w.cprod_src_id
FROM wip_care_product w

-- Exclude records already present in silver_rdm_care_product
LEFT JOIN silver_rdm_care_product r
    ON w.cprod_src_sys_inst_id = r.cprod_src_sys_inst_id
   AND w.cprod_src_id = r.cprod_src_id

WHERE r.cprod_src_id IS NULL

# %%
Investigated and finalized WIP Care Product derivation logic based on Monday definitions. Confirmed cprod_name is derived using Service Type + Service Activity + Activity Type, and cprod_src_id using Service Type ID + Service Activity ID + Activity Type ID. Validated required joins across WIP source tables and applied is_primary = true filter with null checks to retain only valid combinations. Compared the derived WIP set against existing silver_rdm_care_product records and prepared final query to return only new records with the required 3 columns: cprod_name, cprod_src_sys_inst_id, and cprod_src_id. Temporarily hardcoded cprod_src_sys_inst_id as WIP001, to be replaced later with dynamic lookup once the Source System Instance reference list is available in Fabric.

# %%
Investigation and implementation completed for WIP Care Product derivation. Reviewed the Monday attribute definitions and identified that for WIP, cprod_name must be derived as a concatenation of Service Type, Service Activity, and Activity Type, while cprod_src_id must be derived as a concatenation of Service Type ID, Service Activity ID, and Activity Type ID.

Validated the WIP source structure and confirmed the required joins across the following tables:

silver_wip_activityentry

silver_wip_activityheader

silver_wip_activityservice

silver_wip_servicetype

silver_wip_service

silver_wip_activitytype

Derived mapping finalized as below:

cprod_name = servicetype.description + service.description + activitytype.description

cprod_src_id = service_type_id + '_' + service_id + '_' + activity_type_id

cprod_src_sys_inst_id = temporarily hardcoded as WIP001

Applied is_primary = true filter on silver_wip_activityservice to use the primary service mapping for care product derivation. Added null checks to exclude incomplete combinations. Compared the derived WIP care product set against existing records in silver_rdm_care_product using cprod_src_sys_inst_id and cprod_src_id, and filtered to return only new records not already present in the RDM care product table.

Final output/query prepared for WIP with only the required 3 columns:

cprod_name

cprod_src_sys_inst_id

cprod_src_id

Note: cprod_src_sys_inst_id is currently hardcoded because the Source System Instance reference list is not yet available in Fabric. This can be replaced later with a dynamic lookup once that reference table is ingested.

# %%
हा कोड काय करतो

हा कोड WIP source tables मधून नवीन Care Product records काढतो.

आपल्याला final output मध्ये फक्त 3 columns पाहिजेत:

cprod_name

cprod_src_sys_inst_id

cprod_src_id

आणि हे records फक्त तेच हवे जे silver_rdm_care_product मध्ये आधीपासून नाहीत.

कोडचा flow step by step
1) WITH wip_care_product AS (...)

हा पहिला भाग temporary result set तयार करतो.

इथे आपण WIP च्या वेगवेगळ्या tables join करून care product derive करतो.

2) cprod_name

हे Monday definition वरून बनवलं:

Service Type

Service Activity

Activity Type

म्हणून:

ast.description = Service Type

srv.description = Service

atp.description = Activity Type

हे तिन्ही concatenate करून cprod_name बनवलं.

उदा:

Guided Self Help

Appointment

Telephone

तर final:

Guided Self Help Appointment Telephone

3) cprod_src_sys_inst_id

हे सध्या hardcoded:

WIP001

कारण source system instance reference table अजून Fabric मध्ये आलेला नाही.
म्हणून तात्पुरता hardcode केला.

4) cprod_src_id

हे unique source identifier आहे.

हे 3 IDs concatenate करून बनवलं:

ah.service_type_id

asv.service_id

ae.activity_type_id

म्हणजे:

Service Type ID

Service ID

Activity Type ID

उदा:

38

285

1

तर:

38_285_1

joins कशासाठी केले
silver_wip_activityentry ae

हा main starting table आहे.
यात activity related ids आहेत.

silver_wip_activityheader ah

हे join केलं कारण यात:

service_type_id

मिळतो.

Join:

ae.activity_header_id = ah.id

silver_wip_activityservice asv

हे join केलं कारण यात:

service_id

is_primary

आहे.

Join:

ae.activity_service_id = asv.id

silver_wip_servicetype ast

हे join केलं कारण service_type_id चा description हवा होता.

Join:

ah.service_type_id = ast.id

silver_wip_service srv

हे join केलं कारण service_id चा description हवा होता.

Join:

asv.service_id = srv.id

silver_wip_activitytype atp

हे join केलं कारण activity_type_id चा description हवा होता.

Join:

ae.activity_type_id = atp.id

DISTINCT का घेतलं

एकच care product combination source मध्ये multiple times असू शकतो.
पण आपल्याला add table साठी unique combinations हवेत.

म्हणून:

duplicate rows काढून टाकण्यासाठी DISTINCT घेतलं.

is_primary = true का घेतलं

हा खूप important point आहे.

silver_wip_activityservice table मध्ये:

service_id

activity_header_id

is_primary

होतं.

याचा अर्थ एकाच activity header साठी कदाचित एकापेक्षा जास्त service mappings असू शकतात:

primary service

secondary / additional service

आपल्याला care product derive करताना main business service घ्यायची होती.
म्हणून is_primary = true घेतलं.

हा decision कसा घेतला

हा decision आपण data बघून घेतला.

कारण:

एका header ला multiple service rows असण्याची शक्यता दिसत होती

care product definition singular form मध्ये होती, म्हणजे एक clear combination हवा होता

जर multiple service rows घेतल्या असत्या, तर same activity साठी multiple care products तयार झाले असते

business meaning ने primary service हा safest choice आहे

म्हणून आपण main mapping म्हणून primary service निवडली.

is_primary = true घेतलं नसतं तर काय झालं असतं

खूप important.

जर हा filter नसता, तर:

1) duplicate-like combinations वाढले असते

एकाच activity/header साठी multiple services आल्या असत्या.

2) extra/unwanted care products तयार झाले असते

जे actual primary business mapping नाहीत.

3) cprod_name चुकीचा किंवा inflated dataset दिला असता

उदा. एकाच service type आणि activity type सोबत 2-3 वेगवेगळ्या services जोडल्या गेल्या असत्या.

4) cprod_src_id count जास्त झाला असता

म्हणजे source मध्ये खरेच तेवढे unique care products आहेत का, की secondary mappings मुळे वाढलेत, हे समजणं कठीण झालं असतं.

5) SharePoint add list मध्ये unnecessary rows गेल्या असत्या

मग business users ना जास्त cleanup करावा लागला असता.

simple example

समज:
एका activity header साठी:

Service Type = Counselling

Activity Type = Telephone

आणि activityservice मध्ये 2 rows आहेत:

Appointment, is_primary = true

Follow Up, is_primary = false

जर filter लावला:

Care product = Counselling Appointment Telephone

जर filter नाही लावला:

Counselling Appointment Telephone

Counselling Follow Up Telephone

म्हणजे 1 expected row ऐवजी 2 rows आले असते.

त्यामुळे noise वाढतो.

null checks का घेतले

हे conditions:

ah.id IS NOT NULL

ah.service_type_id IS NOT NULL

asv.service_id IS NOT NULL

ae.activity_type_id IS NOT NULL

हे incomplete combinations काढून टाकण्यासाठी घेतले.

कारण सुरुवातीच्या validation query मध्ये काही rows मध्ये nulls येत होते.
Null values असतील तर:

cprod_name incomplete होईल

cprod_src_id चुकीचा होईल

म्हणून फक्त complete valid combinations ठेवले.

final select मध्ये compare का केलं

शेवटी:

derived WIP care products

silver_rdm_care_product

सोबत compare केले.

Join केला:

cprod_src_sys_inst_id

cprod_src_id

वर.

कारण हे दोन fields मिळून source-side unique identity देतात.

मग:

WHERE r.cprod_src_id IS NULL

लावून फक्त नवीन records घेतले.

म्हणजे जे आधीच silver_rdm_care_product मध्ये आहेत ते पुन्हा add होणार नाहीत.

full code summary in simple language

हा कोड:

WIP tables मधून service type, service, activity type जोडतो

त्यातून cprod_name बनवतो

त्यांच्या ids मधून cprod_src_id बनवतो

source instance id म्हणून तात्पुरता WIP001 देतो

फक्त primary service mappings घेतो

incomplete rows काढतो

unique combinations ठेवतो

existing silver_rdm_care_product सोबत compare करतो

फक्त नवीन records return करतो

Senior ला सांगायची short explanation

We used the primary service mapping because one activity header can potentially link to multiple service rows. For care product derivation, we needed a single business-relevant combination, so we filtered to is_primary = true to avoid duplicate or secondary service mappings generating extra care product records. Without this filter, the output would contain inflated and potentially incorrect combinations for the same underlying activity.
