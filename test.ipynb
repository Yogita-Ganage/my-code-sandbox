# %%
model

# %%
Hi Mali, just wanted to confirm whether the Care Product SharePoint list is now completed/finalized, as the version currently visible in Fabric looks like an older one. Also, once it is finalized, please add and retain some demo rows in the SharePoint list for demo/testing.

# %%
Investigated Care Product RDM add-table implementation. Reviewed silver_rdm_care_product, related attribute definitions, and source system/source system instance values for WIP, MPB, and S1. Confirmed the correct approach is to use system-specific source tables instead of the final conformed silver_care_product table. For WIP, identified source path via silver_wip_servicetype and silver_rdm_wip_product_service_mapping. Also noted that the SharePoint-to-Silver dataflow currently visible in Fabric appears to be an older version. Pending confirmation from Mali on whether the Care Product SharePoint list is finalized, and demo rows need to be added/retained for testing.
