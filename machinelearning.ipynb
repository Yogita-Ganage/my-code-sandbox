# %%
# %%sql
# SELECT z_src_system_id, COUNT(*) as cnt
# FROM silver_care_episode
# GROUP BY z_src_system_id
# ORDER BY z_src_system_id

# %%
# %%sql
# SELECT care_epi_is_test, COUNT(*) as cnt
# FROM silver_care_episode
# WHERE z_src_system_id = 'WIP'
# GROUP BY care_epi_is_test
# ORDER BY care_epi_is_test

# %%
Completed WIP mapping for CARE EPISODE.care_epi_is_test. As no single direct test flag is available in WIP, the attribute was derived using rule-based logic based on approved definition and DevOps investigation. Implemented 1/0 flag using known test customer names and raised-in-error service descriptions, and validated output successfully.

# %%
WIP

ahrd.customer_name → test customer names / contract-style checks

servt.description → service description / raised in error logic

SONE

p.test_patient → patient-level test flag

source originally from bronze_sone_srpatient.TestPatient, then brought into silver_sone_srpatient

MPB

ten.name from silver_drj_tenancies → test tenancy logic
