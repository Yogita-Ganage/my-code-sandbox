# %%
-- Monday definition / DevOps confirmed logic for WIP test cases
,CASE
    WHEN left(lower(trim(ahrd.customer_name)), 6) = 'test -' THEN 1
    WHEN lower(trim(ahrd.customer_name)) = 'testy ltd' THEN 1
    WHEN lower(trim(ahrd.customer_name)) = 'testing testing 12' THEN 1
    WHEN lower(trim(servt.description)) IN ('case raised in error', 'bnssg - case raised in error') THEN 1
    ELSE 0
END AS care_epi_is_test
